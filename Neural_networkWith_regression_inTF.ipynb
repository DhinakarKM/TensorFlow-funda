# %% [markdown]
# <a href="https://colab.research.google.com/github/DhinakarKM/TensorFlow-funda/blob/main/Neural_networkWith_regression_inTF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %% [markdown]
# # Creating data to view and fit

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([1,2,3,4,5,6,7])
Y = np.array([2,1,4,3,6,5,8])
plt.scatter(X,Y)

# %%
X = tf.constant(X)
Y = tf.constant(Y)
X,Y
# Out:
# (<tf.Tensor: shape=(7,), dtype=int64, numpy=array([1, 2, 3, 4, 5, 6, 7])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([2, 1, 4, 3, 6, 5, 8])>)

# %%
tf.random.set_seed(30)
#creting a model using s
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

#compiling the model
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=['mae'])

#fitting the model
# model.fit(X, y, epochs=5) # this will break with TensorFlow 2.7.0+
model.fit(tf.expand_dims(X, axis=-1), Y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step - loss: 1.5007 - mae: 1.5007
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3780 - mae: 1.3780
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.2662 - mae: 1.2662
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.2121 - mae: 1.2121
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.1580 - mae: 1.1580
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.1039 - mae: 1.1039
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.0828 - mae: 1.0828
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.0793 - mae: 1.0793
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.0758 - mae: 1.0758
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.0724 - mae: 1.0724

# %%
X,Y
# Out:
# (<tf.Tensor: shape=(7,), dtype=int64, numpy=array([1, 2, 3, 4, 5, 6, 7])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([2, 1, 4, 3, 6, 5, 8])>)

# %%
model.predict(tf.expand_dims([8],axis=-1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# array([[6.9983816]], dtype=float32)

# %% [markdown]
# #improve a model
#
# **1. Creating a model** - here you might want to add more layers, increase the number of hidden units (also called neurons) within each layer, change the activation functions of each layer.
#
# **2. Compiling model** -  you might want to choose optimization function or perhaps change the learning rate of the optimization function.
#
# **3. Fitting a model** - perhaps you could fit a model for more epochs (leave it training for longer) or on more data (give the model more examples to learn from).

# %%
#let's rebuild the model

#create a model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(100,activation="relu"),#extra hidden layer with 100 hidden units(neurons)
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(1)
])
#compiling the model

model.compile(loss="mae",
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
              metrics=['mae'])

#fit the model
model.fit(tf.expand_dims(X,axis=-1),Y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 4.4627 - mae: 4.4627
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 4.4421 - mae: 4.4421
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 4.4215 - mae: 4.4215
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 4.4009 - mae: 4.4009
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 4.3804 - mae: 4.3804
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 4.3602 - mae: 4.3602
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 4.3407 - mae: 4.3407
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 4.3215 - mae: 4.3215
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 4.3022 - mae: 4.3022
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 4.2829 - mae: 4.2829
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 4.2636 - mae: 4.2636
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 4.2443 - mae: 4.2443
# ...

# %%
Y_pred = model.predict(tf.expand_dims(19,axis=-1))
Y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# array([[6.7635794]], dtype=float32)

# %% [markdown]
# #  Evaluate the model

# %%
X = tf.range(-1000,1000,4)
X
# Out:
# <tf.Tensor: shape=(500,), dtype=int32, numpy=
# array([-1000,  -996,  -992,  -988,  -984,  -980,  -976,  -972,  -968,
#         -964,  -960,  -956,  -952,  -948,  -944,  -940,  -936,  -932,
#         -928,  -924,  -920,  -916,  -912,  -908,  -904,  -900,  -896,
#         -892,  -888,  -884,  -880,  -876,  -872,  -868,  -864,  -860,
#         -856,  -852,  -848,  -844,  -840,  -836,  -832,  -828,  -824,
#         -820,  -816,  -812,  -808,  -804,  -800,  -796,  -792,  -788,
#         -784,  -780,  -776,  -772,  -768,  -764,  -760,  -756,  -752,
#         -748,  -744,  -740,  -736,  -732,  -728,  -724,  -720,  -716,
#         -712,  -708,  -704,  -700,  -696,  -692,  -688,  -684,  -680,
#         -676,  -672,  -668,  -664,  -660,  -656,  -652,  -648,  -644,
#         -640,  -636,  -632,  -628,  -624,  -620,  -616,  -612,  -608,
#         -604,  -600,  -596,  -592,  -588,  -584,  -580,  -576,  -572,
#         -568,  -564,  -560,  -556,  -552,  -548,  -544,  -540,  -536,
# ...

# %%
Y = X+10
Y
# Out:
# <tf.Tensor: shape=(500,), dtype=int32, numpy=
# array([-990, -986, -982, -978, -974, -970, -966, -962, -958, -954, -950,
#        -946, -942, -938, -934, -930, -926, -922, -918, -914, -910, -906,
#        -902, -898, -894, -890, -886, -882, -878, -874, -870, -866, -862,
#        -858, -854, -850, -846, -842, -838, -834, -830, -826, -822, -818,
#        -814, -810, -806, -802, -798, -794, -790, -786, -782, -778, -774,
#        -770, -766, -762, -758, -754, -750, -746, -742, -738, -734, -730,
#        -726, -722, -718, -714, -710, -706, -702, -698, -694, -690, -686,
#        -682, -678, -674, -670, -666, -662, -658, -654, -650, -646, -642,
#        -638, -634, -630, -626, -622, -618, -614, -610, -606, -602, -598,
#        -594, -590, -586, -582, -578, -574, -570, -566, -562, -558, -554,
#        -550, -546, -542, -538, -534, -530, -526, -522, -518, -514, -510,
#        -506, -502, -498, -494, -490, -486, -482, -478, -474, -470, -466,
# ...

# %%
#visualize the data
import matplotlib.pyplot as plt
plt.scatter(X,Y)

# %% [markdown]
# # **Split data into training/test set**
#
# One of the other most common and important steps in a machine learning project is creating a training and test set (and when required, a validation set).
#
# Each set serves a specific purpose:
#
# **Training set -** the model learns from this data, which is typically 70-80% of the total data available (like the course materials you study during the semester).
#
# **Validation set-** the model gets tuned on this data, which is typically 10-15% of the total data available (like the practice exam you take before the final exam).
#
# **Test set -** the model gets evaluated on this data to test what it has learned, it's typically 10-15% of the total data available (like the final exam you take at the end of the semester).

# %%
X_train = X[:400]
Y_train = Y[:400]
X_test = Y[400:]
Y_test = Y[400:]
len(X_train),len(Y_train),len(X_test),len(Y_test)
# Out:
# (400, 400, 100, 100)

# %% [markdown]
# Visualize the data

# %%
plt.figure(figsize=(10,7))
plt.scatter(X_train,Y_train,c="g",label="Training data")
plt.scatter(X_test,Y_test,c="r",label="Testing data")
plt.legend()

# %%
#let's create a neural network
# create a model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(100,input_shape=[1],name="Input_layer",activation="relu"),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(1)
])
#compile a model
model.compile( loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=["mae"])
#fit the model
model.fit(tf.expand_dims(X_train,axis=-1),Y_train,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 402.8278 - mae: 402.8278
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 145.3089 - mae: 145.3089
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.2638 - mae: 43.2638
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.4175 - mae: 18.4175
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7512 - mae: 8.7512
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7056 - mae: 6.7056
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9523 - mae: 4.9523
# Epoch 8/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_layer (Dense)             │ (None, 100)            │           200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,205 (121.90 KB)
#  Trainable params: 10,401 (40.63 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 20,804 (81.27 KB)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
Y_pred = model.predict(tf.expand_dims(X_test,axis=-1))
Y_pred
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# array([[ 625.79626],
#        [ 629.84814],
#        [ 633.9    ],
#        [ 637.952  ],
#        [ 642.00385],
#        [ 646.05585],
#        [ 650.1077 ],
#        [ 654.1597 ],
#        [ 658.21155],
#        [ 662.26355],
#        [ 666.3154 ],
#        [ 670.3673 ],
#        [ 674.41925],
#        [ 678.47125],
#        [ 682.5231 ],
#        [ 686.575  ],
#        [ 690.62695],
#        [ 694.6788 ],
#        [ 698.73065],
#        [ 702.78265],
#        [ 706.8346 ],
#        [ 710.8865 ],
#        [ 714.93835],
#        [ 718.99036],
#        [ 723.0422 ],
#        [ 727.0942 ],
#        [ 731.14606],
#        [ 735.1979 ],
#        [ 739.2499 ],
#        [ 743.3018 ],
#        [ 747.3537 ],
#        [ 751.4057 ],
#        [ 755.4576 ],
#        [ 759.5094 ],
#        [ 763.5614 ],
#        [ 767.61334],
#        [ 771.6652 ],
#        [ 775.71716],
#        [ 779.7691 ],
#        [ 783.821  ],
#        [ 787.873  ],
# ...

# %%
Y_test
# Out:
# <tf.Tensor: shape=(100,), dtype=int32, numpy=
# array([ 610,  614,  618,  622,  626,  630,  634,  638,  642,  646,  650,
#         654,  658,  662,  666,  670,  674,  678,  682,  686,  690,  694,
#         698,  702,  706,  710,  714,  718,  722,  726,  730,  734,  738,
#         742,  746,  750,  754,  758,  762,  766,  770,  774,  778,  782,
#         786,  790,  794,  798,  802,  806,  810,  814,  818,  822,  826,
#         830,  834,  838,  842,  846,  850,  854,  858,  862,  866,  870,
#         874,  878,  882,  886,  890,  894,  898,  902,  906,  910,  914,
#         918,  922,  926,  930,  934,  938,  942,  946,  950,  954,  958,
#         962,  966,  970,  974,  978,  982,  986,  990,  994,  998, 1002,
#        1006], dtype=int32)>

# %%
def plot_predictions(train_data=X_train,
                     train_labels=Y_train,
                     test_data=X_test,
                     test_labels=Y_test,
                     predictions=Y_pred):
  plt.figure(figsize=(10,7))
  plt.scatter(train_data,train_labels,c="r",label="Training data")
  plt.scatter(test_data,test_labels,c="b",label="Testing data")
  plt.scatter(test_data,predictions,c="g",label="predictions")
  plt.legend()
plot_predictions()

# %%
model.evaluate(tf.expand_dims(X_test,axis=-1),Y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.8054 - mae: 17.8054
# [18.366107940673828, 18.366107940673828]

# %%
#calculate the mae
mae=tf.keras.losses.mae(Y_test,tf.squeeze(Y_pred))
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=18.366107940673828>

# %%
#calculate MSE
tf.keras.losses.mse(Y_test,tf.squeeze(Y_pred))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=339.559814453125>

# %% [markdown]
# # **Let's do 3 models...**

# %% [markdown]
# # model 1

# %%
tf.random.set_seed(30)
#create a model
model_1=tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])
#compilng the model
model_1.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=["mae"])
#fit the model
model_1.fit(tf.expand_dims(X_train,axis=-1),Y_train,epochs=100)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 276.8832 - mae: 276.8832
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 271.3664 - mae: 271.3664
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 265.8529 - mae: 265.8529
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 260.3369 - mae: 260.3369
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 254.8184 - mae: 254.8184
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 249.2981 - mae: 249.2981
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 243.7765 - mae: 243.7765
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 238.2538 - mae: 238.2538
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 232.7304 - mae: 232.7304
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 227.2065 - mae: 227.2065
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 221.6821 - mae: 221.6821
# Epoch 12/100
# ...

# %%
Y_pred1=model_1.predict(X_test)
plot_predictions(predictions=Y_pred1)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f2bcd15b4c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ...

# %%
#creating the model 1 evaluation
mae_1= tf.keras.losses.mae(Y_test,tf.squeeze(Y_pred1))
mse_1= tf.keras.losses.mse(Y_test,tf.squeeze(Y_pred1))
mae_1,mse_1
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=8.56576919555664>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=75.08409881591797>)

# %% [markdown]
# # Model 2
#
# 2 dense layer

# %%
tf.random.set_seed(30)
#create a model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])
#compile the model
model_2.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                metrics=["mse"])
#fit the model
model_2.fit(tf.expand_dims(X_train,axis=-1),Y_train,epochs=100)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 218.4221 - mse: 67427.3828
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 176.4111 - mse: 43964.5430
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 133.6831 - mse: 25243.5039
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 90.0397 - mse: 11476.3926
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.5160 - mse: 2994.7979
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.2962 - mse: 138.5804
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.9432 - mse: 251.7535
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0885 - mse: 97.8143
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8928 - mse: 81.7128
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3610 - mse: 78.6686
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3278 - mse: 79.1087
# Epoch 12/100
# ...

# %%
#plot prediction of model 2
Y_pred2=model_2.predict(X_test)
plot_predictions(predictions=Y_pred2)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
#calculate model_2 evaluation metrics

mae_2=tf.keras.losses.mae(Y_test,tf.squeeze(Y_pred2))
mse_2=tf.keras.losses.mse(Y_test,tf.squeeze(Y_pred2))
mae_2,mse_2
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.845839262008667>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=1.0726934671401978>)

# %% [markdown]
# # Build Model 3
#
# 2 layers trained for 500 epochs

# %%
tf.random.set_seed(30)
#create a model
model_3=tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])
#compile the model
model_3.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                metrics=["mae"])
#fit the model
model_3.fit(tf.expand_dims(X_train,axis=-1),Y_train,epochs=500)
# Out:
# Epoch 1/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 343.3697 - mae: 343.3697
# Epoch 2/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 296.7582 - mae: 296.7582
# Epoch 3/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 250.1486 - mae: 250.1486
# Epoch 4/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 203.4372 - mae: 203.4372
# Epoch 5/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 156.5713 - mae: 156.5713
# Epoch 6/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 109.5031 - mae: 109.5031
# Epoch 7/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.2926 - mae: 62.2926
# Epoch 8/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.0703 - mae: 18.0703
# Epoch 9/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.6098 - mae: 14.6098
# Epoch 10/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5683 - mae: 9.5683
# Epoch 11/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6948 - mae: 7.6948
# Epoch 12/500
# ...

# %%
#plot prediction for model 3
Y_pred3=model_3.predict(X_test)
plot_predictions(predictions=Y_pred3)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
#calculate model_3 evaluation metrics
mae_3=tf.keras.losses.mae(Y_test,tf.squeeze(Y_pred3))
mse_3=tf.keras.losses.mse(Y_test,tf.squeeze(Y_pred3))
mae_3,mse_3
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=10.836821556091309>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=117.45166778564453>)

# %% [markdown]
# # Compaing the models with pandas dataframes

# %%
import pandas as pd

model_results = [["model_1",mae_1.numpy(),mse_1.numpy()],
                 ["model_2",mae_2.numpy(),mse_2.numpy()],
                 ["moedl_3",mae_3.numpy(),mse_3.numpy()]]
results = pd.DataFrame(model_results,columns=["model","mae","mse"])
results
# Out:
#      model        mae         mse
# 0  model_1   8.565769   75.084099
# 1  model_2   0.845839    1.072693
# 2  moedl_3  10.836822  117.451668

# %%
model_2.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 10)             │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95 (384.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 64 (260.00 B)

# %%
model_2.save("saved_model_2.keras")

# %%
#loading the save model
loaded_saved_model = tf.keras.models.load_model("saved_model_2.keras")
loaded_saved_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 10)             │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95 (384.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 64 (260.00 B)

# %% [markdown]
# # **A Larger Model**

# %%
#import required libraries
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read insurance dataset
insurance = pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/refs/heads/master/insurance.csv")
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#one hot encode our dataframe so its all numbers
insurance_one_hot = pd.get_dummies(insurance)
insurance_one_hot
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
X = insurance_one_hot.drop("charges",axis=1)
Y = insurance_one_hot["charges"]

# %%
X.head()
Y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
#creating training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)
len(X),len(X_train),len(X_test)
# Out:
# (1338, 936, 402)

# %%
#Build a model of neural network
tf.random.set_seed(50)
#1 create a model
insurance_model = tf.keras.Sequential([
    tf.keras.layers.Dense(500),
    tf.keras.layers.Dense(500),
    tf.keras.layers.Dense(500),
    tf.keras.layers.Dense(1)
])
#2 compiling the model
insurance_model.compile(loss=tf.keras.losses.mae,
                        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                        metrics=["mae"])
#3 fit the model
# Convert boolean columns to integers before casting
X_train_casted = X_train.astype(int).astype(float)
history = insurance_model.fit(X_train_casted,Y_train,epochs=200)
# Out:
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 11623.6602 - mae: 11623.6602
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7422.9404 - mae: 7422.9404
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6979.1392 - mae: 6979.1392
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6726.3496 - mae: 6726.3496
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6666.5732 - mae: 6666.5732
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6573.7100 - mae: 6573.7100
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6465.1187 - mae: 6465.1187
# Epoch 8/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6334.2437 - mae: 6334.2437
# Epoch 9/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6133.4434 - mae: 6133.4434
# Epoch 10/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5745.9546 - mae: 5745.9546
# Epoch 11/200
# ...

# %%
insurance_model.evaluate(X_test,Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3278.4802 - mae: 3278.4802
# [3211.0625, 3211.0625]

# %%
#plot history (also known as loss curve or training curve)
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 🤔 Question: How long should you train for?
#
# it depends on the problem, so tensorflow has a solution,it's called **EarlyStopping Callback**,which is a tensorflow component which stops training once it stops improving a certain metric.

# %% [markdown]
# # Preprocessing the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

insurance = pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv")
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
from sklearn.model_selection import train_test_split

#create a coloumn transformer
ct =make_column_transformer(
    (MinMaxScaler(),["age","bmi","children"]),
    (OneHotEncoder(handle_unknown="ignore"),["sex","smoker","region"])
)
#create X and Y
X=insurance.drop("charges",axis=1)
Y=insurance["charges"]

#Build our train and test data
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

#fit the coloumn transformer to our training data
ct.fit(X_train)

#Transform training and test data with normalization (minmascaler) and One hot encoder
X_train_normal = ct.transform(X_train)
X_test_normal = ct.transform(X_test)

# %% [markdown]
# # **Build a model**

# %%
tf.random.set_seed(40)
#create a model
insurance_model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(500),
    tf.keras.layers.Dense(500),
    tf.keras.layers.Dense(1)
])

#compiling the model
insurance_model_2.compile(loss=tf.keras.losses.mae,
                          optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                          metrics=["mae"])
#fit the model
insurance_model_2.fit(X_train_normal,Y_train,epochs=200)
# Out:
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 12881.7861 - mae: 12881.7861
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12610.8066 - mae: 12610.8066
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11347.4609 - mae: 11347.4609
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8963.7656 - mae: 8963.7656
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7888.0000 - mae: 7888.0000
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7699.3203 - mae: 7699.3203
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7463.7505 - mae: 7463.7505
# Epoch 8/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7223.8486 - mae: 7223.8486
# Epoch 9/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6946.7759 - mae: 6946.7759
# Epoch 10/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6613.5410 - mae: 6613.5410
# Epoch 11/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6192.6353 - mae: 6192.6353
# ...

# %%
insurance_model_2.evaluate(X_test_normal,Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3222.8215 - mae: 3222.8215
# [3155.334228515625, 3155.334228515625]
